# %% [markdown]
# # İsim Soyisim: Ömer Cebeci
# # Numara: 171024007
# # Ekip No A10

# %%
import numpy as np 
import matplotlib.pyplot as plt
import scipy.signal as sgnl
from  matplotlib import patches
from matplotlib.figure import Figure
from matplotlib import rcParams
import math
# %matplotlib notebook

# %% [markdown]
# # ÖN ÇALIŞMA

# %% [markdown]
# # Örnek-1

# %%
F=100 # işaretin temel frekansı 
T=1/F  #işaretin temel periyodu
t=np.arange(0,2*T,0.0001) # 2 periyot
x=5*np.cos(200*np.pi*t)
plt.xlabel("t")
plt.title("x(t)=5*cos(200*pi*t)")
plt.plot(t,x) # işaretin grafiğinin çizdirilmesi
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# # Örnek 2:

# %%
Fs=2200 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=22 # örnek sayısının tanımlanması
n=np.arange(0.,2*N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması
xn=5*np.cos(200*np.pi*n*Ts) #örneklenmiş x[n] işaretinin tanımlanması
plt.figure()
plt.stem(n,xn) # x[n] işaretinin grafiğinin çizdirilmesi
plt.title("x[n]") # x[n] işaretinin grafiğinin isimlendirilmesi
plt.xlabel("örnek") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("x[n]") # grafiğin y ekseninin isimlendirilmesi
plt.show() # grafiğin gösterilmesi
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   import sys

# %% [markdown]
# # EK ÇALIŞMA

# %%
 # FS=550
Fs=550 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=11 # örnek sayısının tanımlanması
n=np.arange(0.,2*N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması
xn=5*np.cos(200*np.pi*n*Ts) #örneklenmiş x[n] işaretinin tanımlanması
plt.figure()
plt.stem(n,xn) # x[n] işaretinin grafiğinin çizdirilmesi
plt.title("x[n]") # x[n] işaretinin grafiğinin isimlendirilmesi
plt.xlabel("örnek") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("x[n]") # grafiğin y ekseninin isimlendirilmesi
plt.show() # grafiğin gösterilmesi
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:8: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %% [markdown]
# # Örnek-4

# %%
def signall(Fs,N,k): # Fs: Örnekleme frekansı
    # N : çizdirilmek istenen toplam örnek sayısı
    # k = x(t) işaretinin kaç periyot çizdirileceği
    F=100
    T=1/F
    t = np.linspace(-k*T/2,k*T/2,1000)
    xt = np.sinc(2*F*t)**2 # sürekli zamanlı işaret
    Ts=1/Fs
    
    n = np.arange(-N/2, N/2) # x[n] işaretinin indis ekseninin tanımlanması
    xn = np.sinc(2*F*n*Ts)**2 # x[n] işaretinin tanımlanması
    
    # x[n] işaretinin fourier transformu
    w = np.arange(-np.pi, np.pi, 2*np.pi/N) # omega ekseninin -pi ile +pi arasında tanımlanması
    xw = np.fft.fftshift(np.fft.fft(xn,N)/N) # ayrık zamanlı işaretin Fourier transformu
    
    plt.figure()
    plt.subplot(1,3,1)
    plt.plot(t,xt) # sürekli zamanlı x(t) işaretinin grafiğinin çizdirilmesi
    plt.xlabel("t (sn)") # grafiğin x ekseninin isimlendirilmesi
    plt.title("$x(t)$") # grafiğin y ekseninin isimlendirilmesi
    
    
    plt.subplot(1,3,2)
    plt.stem(n,xn) # x[n] işaretinin grafiğinin çizdirilmesi
    plt.xlabel("n (örnek)") # grafiğin x ekseninin isimlendirilmesi
    plt.title("$x[n]$") # grafiğin y ekseninin isimlendirilmesi
    
    
    plt.subplot(1,3,3)
    plt.stem(w/np.pi,abs(xw)) # X(w) işaretinin grafiğinin çizdirilmesi
    plt.xlabel("$\omega$ / $\pi$") # grafiğin x ekseninin isimlendirilmesi
    plt.title("$X(\omega)$ (Genlik)") # grafiğin y ekseninin isimlendirilmesi
    plt.show()

# %%
signall(1000,30,3) # Fs= 1000 Hz , N = 30 örnek , x(t) toplam 3 periyot için çizdirildi
signall(600,30,5) # Fs= 600 Hz , N = 30 örnek , x(t) toplam 5 periyot içi çizdirildi
signall(300,30,10) # Fs= 300 Hz , N = 30 örnek , x(t) toplam 10 periyotta çizdirildi
signall(100,30,30) # Fs= 100 Hz , N = 30 örnek , x(t) toplam 3 periyotta çizdirildi
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:22: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:28: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">

# %% [markdown]
# # Örnek-5

# %%
Fs=2200 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=22
n=np.arange(0.,2*N) 
xn=5*np.cos(200*np.pi*n*Ts)

# %%
plt.stem(n,xn) 
plt.title("x[n]") 
plt.xlabel("örnek") 
plt.ylabel("x[n]") 
plt.show()
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.

# %%
w=np.linspace(-np.pi,np.pi-(2*np.pi/N),N) # -pi,pi aralığında N örnek olacak şekilde x ekseni değerleri etik
x_w=np.fft.fft(xn,N)/N # x[n] işaretinin fourier transformunun alınması
x_w=np.fft.fftshift(x_w) # x(w) işaretinin fftshift ile -pi,+pi aralığında gösterilmesi

# %%
plt.figure() #yeni bir figure penceresi açar
plt.stem(w,np.abs(x_w)) # x(w) işaretinin genlik değerlerinin bulunması ve grafiğinin çizdirilmesi
plt.title("X(w)'nın Genlik Grafiği") # grafiğin isimlendirilmesi
plt.xlabel("w") # grafiğin x ekseninin isimlendirilmesi
plt.show() # grafiklerin gösterilmesini sağlar
plt.figure() #yeni bir figure penceresi açar
plt.stem(w,np.angle(x_w)) # x_(w) işaretinin faz değerlerinin bulunması ve grafiğinin çizdirilmesi
plt.title("X(w)'nın Faz Grafiği") # x_(w) işaretinin fazının grafiğinin isimlendirilmesi
plt.xlabel("w") # grafiğin x ekseninin isimlendirilmesi
plt.show() # grafiklerin gösterilmesini sağlar
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   import sys

# %% [markdown]
# # Örnek-7

# %%
F=100
T=1/F


k=4 # Bu örnek için işareti 4 periyot boyunca çizdirelim
t=np.arange(0.,k*T,0.002/22) # x işaretine ait t değişkeninin tanımlanması
x=5*np.cos(200*np.pi*t) # x(t) işaretinin tanımlanması


plt.figure() # yeni bir figure penceresi açar
plt.xlabel("t") # grafiğin x ekseninin isimlendirilmesi
plt.title("x(t)=5*cos(200*pi*t)") # x[n] işaretinin grafiğinin isimlendirilmesi
plt.plot(t,x) # işaretin grafiğinin çizdirilmesi
plt.show() # grafiklerin gösterilmesini sağlar

# %%
Fs=2200 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=22 # örnek sayısının tanımlanması
n=np.arange(0,k*N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması
xn=5*np.cos(200*np.pi*n*Ts) #örneklenmiş x[n] işaretinin tanımlanması
plt.figure() # yeni bir figure penceresi açar
plt.stem(n,xn) # x[n] işaretinin grafiğinin çizdirilmesi
plt.title("x[n]") # x[n] işaretinin grafiğinin isimlendirilmesi
plt.xlabel("örnek") # grafiğin x ekseninin isimlendirilmesi
plt.ylabel("x[n]") # grafiğin y ekseninin isimlendirilmesi
plt.show() # grafiğin gösterilmesi
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   import sys

# %%
## Geri elde etme işlemi
x_sinc = np.zeros([k*N,np.size(x,axis=0)]) # İşlem sonucunu yazabilmek için oluşturulan yeni dizi
plt.figure() #yeni bir figure penceresi açar
for ni in n:
    x_sinc[ni,:]=xn[ni]*np.sinc((t-(ni)*Ts)/Ts)
    plt.plot(x_sinc[ni,:])
plt.title("işaretin zaman domaininde sinc(.) ile konvolüsyon işlemi ") # Grafik başlığının oluşturulması
plt.xlabel("örnek") # grafiğin x ekseninin isimlendirilmesi
plt.show() # grafiğin gösterilmesi

# %%
xr_t = np.sum(x_sinc, axis=0)
plt.figure() # yeni bir figure penceresi açar
plt.xlabel("t") # grafiğin x ekseninin isimlendirilmesi
plt.title("x_r(t)") # x[n] işaretinin grafiğinin isimlendirilmesi
plt.plot(t,xr_t) # x[n] işaretinin grafiğinin zaman domaininde çizdirilmesi
plt.show() # grafiklerin gösterilmesini sağlar

# %% [markdown]
# # Örnek-8

# %%
F=100 # x işaretinin frekansı
T=1/F # x işaretinin periyodu
k=2 # Periyot sayısı
t=np.arange(0.,k*T,0.00001) # x işaretine ait t değişkeninin tanımlanması
x=5*np.cos(200*np.pi*t) # x(t) işaretinin tanımlanması
plt.figure() # yeni bir figure penceresi açar
plt.xlabel("t") # grafiğin x ekseninin isimlendirilmesi
plt.title("x(t)") # Grafiğin başlığının oluşturulması
plt.plot(t,x) # işaretinin grafiğinin çizdirilmesi
plt.show() # grafiğin gösterilmesi

# %%
Fs=2200 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=22 # bir periyottaki örnek sayısının tanımlanması
n=np.arange(0.,k*N) # örnekleme indisinin 0'dan k periyot olacak şekilde array olarak tanımlanması
xn=5*np.cos(200*np.pi*n*Ts) #örneklenmiş x[n] işaretinin tanımlanması

# %%
### Kuantalama fonksiyonun yazılması
def quantize(x, S):
    X = x.reshape((-1,1))
    S = S.reshape((1,-1))
    dists = abs(X-S)
    nearestIndex = dists.argmin(axis=1)
    quantized = S.flat[nearestIndex]
    return quantized.reshape(x.shape)

# %%
### İşaretin değerlerinin -kbit ile ifade edileceğinin tanımlanması
### ve buna göre gerekli parametrelerinin tanımlanması 
k_bit= 2 # işaret değerlerinin kaç bit ile ifade edileceği
Max_range= np.amax(xn)-np.amin(xn) # işaretin y ekseninde aldığı max değer aralığı
q=pow(2,k_bit) # seviye sayısı
delta = Max_range/q # adım aralığı
S_midrise = -np.amax(xn) + delta/2 + np.arange(q)*delta # mid-rise yöntemi için formül
S_midtread = -np.amax(xn) + np.arange(q)*delta # mid-tread yöntemi için formül

# %%
y_midtrise = quantize(xn, S_midrise) # mid-rise yöntemi ile kuantalanmış değerler
y_midtread = quantize(xn, S_midtread) # mid-tread yöntemi ile kuantalanmış değerler

# %%
plt.figure() #yeni bir figure penceresi açar
fig, ax = plt.subplots()
ax.stem(n,xn) # x[n] işaretinin grafiğinin çizdirilmesi
ax.bar(n,y_midtrise,color='orange',edgecolor = "darkorange") # kuantalanmış işaretin grafiğinin çizdirilmes
plt.xlabel("örnek") # grafiğin x ekseninin isimlendirilmesi
plt.title('midrise yöntemiyle kuantalanmış işaret')
fig, ax = plt.subplots()
ax.stem(n,xn) # x[n] işaretinin grafiğinin çizdirilmesi
ax.bar(n,y_midtread,color='orange',edgecolor = "darkorange") # kuantalanmış işaretin grafiğinin çizdirilmes
plt.xlabel("örnek") # grafiğin x ekseninin isimlendirilmesi
plt.title('midtread yöntemiyle kuantalanmış işaret')
plt.show() # grafiklerin gösterilmesi
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:8: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %% [markdown]
# # ÖDEV-5

# %% [markdown]
#  # SORU-1

# %% [markdown]
# # $ x_1(t)' nin \space örneklenmesi $
# # $200* \pi * n* T =2* \pi *k $
# # $ n= 11*2*k , k=1 \space için: n=22 $
# # $  x_1[n]=7*cos(200*\pi*n*T_s) $ $ (T_s=1/2200)$
# # $ x_1[n]=7*cos( \frac {\pi * n} {11}) $
#
# ################################
# # $ x_2(t)' nin \space örneklenmesi $
# # $ 1.\space kısım \space için \space :200* \pi * n* T_s =2* \pi *k$
# #   $2.\space kısım \space için \space 1800* \pi * n * T_s= 2* \pi* k  $
# # $ 1.\space kısım \space da \space k=1\space için\space N=22 \space,ikinci \space kısımda \space k=9 \space için \space N=22 \space olarak
#  hesaplanmıştır. $
# # $ x_2[n]=3* cos( \frac {200* \pi * n} {2200})+ 4*cos( \frac {1800* \pi * n} {2200})$
# # $  x_2[n]=3*cos( \frac {\pi * n} {11})+ 4*cos( \frac {9* \pi * n} {11})$
# #
# ###############################

# %% [markdown]
# # A)

# %%
Fs=2200 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=22 # k=1 için N=22
n=np.arange(0.,2*N) 
x_1n=7*np.cos(200*np.pi*n*Ts) ## örnekleceneck işaret oluşturuldu 
##çizdirme
plt.figure()
plt.stem(n,x_1n,use_line_collection = True)
plt.title("$ x_1[n] $")
plt.xlabel("örnek") 
plt.ylabel("x[n]") 
plt.show()

# %%
Fs=2200 
Ts=1/Fs
N=22 # k=9 için N=22
n=np.arange(0.,2*N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması
x_2n=3*np.cos(200*np.pi*n*Ts)+4*np.cos(1800*np.pi*n*Ts) 
##çizdirme
plt.figure()
plt.stem(n,x_2n,use_line_collection = True)
plt.title("x_2[n]")
plt.xlabel("örnek")
plt.ylabel("x[n]") 
plt.show()

# %% [markdown]
# #  örnekleme frekansı 2200 Hz, 100 Hz den büyük olduğu için örtüşme olmadan örnekleme gerçekleşebilir.ikinci sinyalde de 4*cos(1800* pi *t) işaretinin frekansı örnekleme frekansının iki katından daha küçük olduğu için örnekleme her iki sinyal içinde örtüşme olmadan yapılır.

# %% [markdown]
# # $ x_2[n]$ sinyali  $ x_1[n]$ sinyali ile  $ 4*cos( \frac {9* \pi * n} {11}) $ sinyallerinin toplamlarından oluşmaktadır.
#
# # İki sinyal arasındaki farkı  $ 4*cos( \frac {9* \pi * n} {11}) $ bu fonksiyondan kaynaklanmaktadır.

# %% [markdown]
# # B)

# %%
#Fs=2200 # örnekleme frekansının tanımlanması
#Ts=1/Fs # örnekleme periyodunun tanımlanması
#N=22 # örnek sayısının tanımlanması
#n=np.arange(0.,2*N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması
#xn=7*np.cos(200*np.pi*n*Ts) #örneklenmiş x[n] işaretinin tanımlanması


## X_1n için

w=np.linspace(-np.pi,np.pi-(2*np.pi/N),N) # -pi,pi 
x_w=np.fft.fft(x_1n,N)/N # x[n] işaretinin fourier transformu
x_w=np.fft.fftshift(x_w) # x(w) işaretinin fftshift ile -pi,+pi aralığında gösterilmesi


##çizdirme
plt.figure()
plt.stem(w,np.abs(x_w)) # x(w) işaretinin genliği
plt.title("X(w)'nın Genlik Grafiği") 
plt.xlabel("w") 
plt.show() 

plt.figure() 
plt.stem(w,np.angle(x_w)) # x_(w) işaretinin fazı
plt.title("X(w)'nın Faz Grafiği") 
plt.xlabel("w") 
plt.show()
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:17: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:23: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
### X_2n için
Fs=2200 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=22 # örnek sayısının tanımlanması
n=np.arange(0.,2*N)
xn=3*np.cos(200*np.pi*n*Ts)+4*np.cos(1800*np.pi*n*Ts) 

w=np.linspace(-np.pi,np.pi-(2*np.pi/N),N) # -pi,pi aralığında N örnek olacak şekilde x ekseni değerleri etik
x_w=np.fft.fft(xn,N)/N # x[n] işaretinin fourier transformunu
x_w=np.fft.fftshift(x_w) # x(w) işaretinin fftshift ile -pi,+pi aralığında gösterilmesi

##çizdirme
plt.figure() 
plt.stem(w,np.abs(x_w),use_line_collection = True) # x(w) işaretinin genlik değerlerinin bulunması ve grafiğinin çizdirilmesi
plt.title("X(w)'nın Genlik Grafiği") 
plt.xlabel("w") 
plt.show() 

plt.figure() 
plt.stem(w,np.angle(x_w),use_line_collection = True) 
plt.title("X(w)'nın Faz Grafiği") 
plt.xlabel("w") 
plt.show()

# %% [markdown]
#
#
# # Genlik grafikleri incelenirse: Bir cos işaretinin fourier dönüşümünde genlik spektrumunda 2 adet dirac gözükmesi gerekir.Birinci sinyalde bir cos'lu sinyal olduğu için 2 adet dirac, ikinci sinyalde 2 adet cos'lu sinyal olduğu için toplam 4 adet dirac gözükmektedir.
# # Birinci işaret de beklenildiği gibi genlikleri $ w= \frac {-\pi} {11} $ ve  $ w=\frac {\pi} {11} $ değerleri için 3.5 olarak gelmiştir.(7/2)
#
#
# # İkinci işarette ise $ w= \frac {-1*\pi} {11} $ ,  $ w= \frac {\pi} {11} $ , $w= \frac {-9*\pi} {11} $, ve$ w=\frac {9*\pi} {11}$ değerlerinde genlikler 2 ve 1.5 değerlerini almıştır. (4/2) ,(3/2)
#
#
# # Her iki işaretinde fazları, genliklerinin sıfırdan farklı olduğu zamanlarda sıfır gelmiştir.

# %% [markdown]
# # C)
# # Birinci sinyal için elde edilen genlik grafiğine bakılacak olursa w=pi/11 ve -pi/11 olacak şekilde iki diractan oluşmuştur.Diracların alanları ise 3.5 olarak gözükmektedir.O zaman işaret 7cos(pi*n/11+0) olarak tahmin edilir.
#
# # İkinci işarete bakılacak olursa aynı birinci işarette olduğu gibi w=pi/11 ve -pi/11 olacak şekilde iki diractan oluşan ve genliği 1.5 olan cos ve w=9*pi/11 ve w= -9*pi/11 olan iki cos  sinyalinden meydana gelmiştir.
# # 3cos(pi*n/11+0) +4 cos(9*pi*n/11+0)
#
# # Genlik değerleri yazımı yapılırken aşağıdaki dönüşüm baz alınarak grafik çizdirilmiştir.
# # $ Acos(\frac {B*pi*n} {C}) -> \frac {A} {2} * (\delta[f-f_0] + \delta[f+f_0]) $ $  \frac {A} {2} =\frac {7} {2} $
# # Elde edilen grafiklerde genliğin değerinin olduğu kısımlarda fazlar sıfırdır.Fazın değer aldığı yerlerde ise genlik sıfırdır.Bu yüzden tahmin edilen xn'ler de faz =0 olarak tahmin edilir.

# %% [markdown]
# # Soru-2

# %% [markdown]
# # $ x_1(t)' nin \space örneklenmesi $
#
# # $ Ts= \frac {1} {1000} $
# # $  x_1[n]=7*cos(200*\pi*n*T_s) \space (t=n*T_s) $
# # $ x_1[n]=7*cos( \frac {\pi * n} {5}) $
# # $ \frac {\pi *n} {5} = 2* \pi * k , \space k=1 \space için N=10 $
# # Örnekleme frekansı işaretin frekansından 2 kat daha fazla olduğu için örnekleme örtüşme olmadan yapılabilir.
# ################################
# # $ x_2(t)' nin örneklenmesi $
# # $ x_2[n]=3* cos( \frac {200* \pi * n} {1000})+ 4*cos( \frac {1800* \pi * n} {1000})$
# # $  x_2[n]=3*cos( \frac {\pi * n} {5})+ 4*cos( \frac {18* \pi * n} {10})$
# # Örnekleme frekansı $4*cos( \frac {1800* \pi * n} {1000})$ işaretinin frekansının 2 katından daha büyük olmadığı için , bu işaret düzgün örneklenemeyecektir.
# ###############################

# %% [markdown]
# # A)
# # Örnek sayısının hesaplanması:
# # $ \frac {n* \pi} {5} = 2* \pi * k $
# # $ k=1 \space için \space N=10 $

# %%
Fs=1000 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=10 # örnek sayısının tanımlanması
n=np.arange(0.,2*N) # 2 periyot ayarlanması
x_1n=7*np.cos(200*np.pi*n*Ts) 
##çizdirme
plt.figure()
plt.stem(n,x_1n,use_line_collection = True) 
plt.title("$ x_1[n] $")
plt.xlabel("örnek") 
plt.ylabel("x[n]") 
plt.show()

# %%
Fs=1000 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=10 # örnek sayısının tanımlanması
n=np.arange(0.,2*N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması
x_2n=3*np.cos(200*np.pi*n*Ts)+4*np.cos(1800*np.pi*n*Ts) ## işaretin tanımlanması
##çizdirme
plt.figure()
plt.stem(n,x_2n,use_line_collection = True) 
plt.title("$ x_2[n] $")
plt.xlabel("örnek") 
plt.ylabel("x[n]") 
plt.show()

# %% [markdown]
# # Yukarıdaki iki işaret de örneklendiğinde ikiside birbirlerinden farklı olmasına rağmen aynı örneklenmiş işaret elde edildi .Yani örtüşme meydana geldi.Bunun sebebi ise örnekleme frekansının 2. çizilen fonksiyonun frekansının iki katından daha büyük olmaması olarak söylenebilir. ($4*cos( \frac {1800* \pi * n} {1000})$)

# %% [markdown]
# # B)

# %%
Fs=1000 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=10 # örnek sayısının tanımlanması


w=np.linspace(-np.pi,np.pi-(2*np.pi/N),N) # -pi,pi aralığında N örnek olacak şekilde x ekseni değerleri etik
x_w=np.fft.fft(x_1n,N)/N # x[n] işaretinin fourier transformunu
x_w=np.fft.fftshift(x_w) # x(w) işaretinin fftshift ile -pi,+pi aralığında gösterilmesi

##çizdirme
plt.figure()
plt.stem(w,np.abs(x_w),use_line_collection = True) 
plt.title("$ X_1(w)'nın Genlik Grafiği$") 
plt.xlabel("w")
plt.show() 

plt.figure() 
plt.stem(w,np.angle(x_w),use_line_collection = True)  
plt.title("$ X_1(w)'nın Faz Grafiği $")
plt.xlabel("w") 
plt.show()

# %% [markdown]
# # Genlik spektrumu incelendiğinde, teorik olarak işaretin cos olmasından dolayı fourier dönüşümü yapılınca sıfırın pi/5 sağında ve solunda iki diractan oluşması beklenir.Grafikte de bu gözlemlenmiştir. Genlik değerleri ise 7* (1/2) den 3.5 olarak gözlemlenmiştir.
# # NOT:Eğer fourier transform alınırken x_w değerleri (1/N) ile çarpılmasa genlik değerleri 7*5*pi olarak okunacaktı.Fakat N'ye bölme işlemi yapıldığı için 7/2 değeri okunuyor.

# %%
Fs=1000 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=10 # örnek sayısının tanımlanması
n=np.arange(0.,2*N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması
xn=3*np.cos(200*np.pi*n*Ts)+4*np.cos(1800*np.pi*n*Ts) #örneklenmiş x[n] işaretinin tanımlanması

w=np.linspace(-np.pi,np.pi-(2*np.pi/N),N) 
x_w=np.fft.fft(xn,N)/N 
x_w=np.fft.fftshift(x_w) # x(w) işaretinin fftshift ile -pi,+pi aralığında gösterilmesi


plt.figure() #yeni bir figure penceresi açar
plt.stem(w,np.abs(x_w),use_line_collection = True) 
plt.title("$ X_2(w)'nın Genlik Grafiği $")
plt.xlabel("w") 
plt.show()
plt.figure() 
plt.stem(w,np.angle(x_w),use_line_collection = True) 
plt.title("$ X_2(w)'nın Faz Grafiği $ ") 
plt.xlabel("w")
plt.show()

# %% [markdown]
# # Örnekleme frekansı (1000) , 1800 Hz'den büyük olmadığı için örnekleme düzgün yapılamamıştır.

# %% [markdown]
# # C)

# %% [markdown]
# # $x_1[n]$'nin genlik grafğine bakılacak olursa w= $\frac {\pi} {5}$ ve w= $\frac {- \pi} {5}$ de alanı 3.5 olan 2 adet diractan oluşmaktadır.
# $ Acos(\frac {B*pi*n} {C}) -> \frac {A} {2} * (\delta[f-f_0] + \delta[f+f_0]) $
# # formulu baz alınarak $x_1[n] = (3.5*2)cos(\frac {\pi} {5})$ tahmin edilir.
#
#
# # $x_2[n]$  sinyali düzgün örneklenememiştir.Bu yüzden sadece sinyalin bir kısmı geri elde edilebilir.Genlik grafiği incelendiğinde  $x_1[n]$ sinyali ile aynı olduğu gözlemlenir.Ve geri elde edilecek sinyal  $x_2[n] = (3.5*2)cos(\frac {\pi} {5})$  olarak tahmin edilir.
#
# # Her iki sinyalde de genliğin değer aldığı (sıfırdan farklı) yerlerde faz sıfır olduğu için her iki sinyalde de faz =0 olarak alınmıştır.

# %% [markdown]
#  # Soru-3

# %% [markdown]
# # $ sin(9600* \pi *t) , F_s=8192, T_s= \frac {1} {8192} $
# # Örnekleme yapılırsa:
# # $ sin(9600* \pi *n*T_s) $
# # $ sin( \frac {9600* \pi *n } {8192}) $

# %%
# a)
F=9600/2 # temel frekans
T=1/F
k=3 # işaretin periyodu
t=np.arange(0.,k*T,0.00001) # x işaretine ait t değişkeninin tanımlanması
x=np.sin(9600*np.pi*t) # x(t) nin yazılması
##çizdirme
plt.figure() 

plt.xlabel("t") 
plt.title("x(t)=sin(9600*pi*t)") 
plt.plot(t,x) 

plt.show()

# %%
# b)
Fs=8192 # örnekleme frekansının tanımlanması
Ts=1/Fs # örnekleme periyodunun tanımlanması
N=128 
n=np.arange(0.,3*N) # örnekleme indisinin 0'dan iki periyot olacak şekilde array olarak tanımlanması
x3n=np.sin(9600*np.pi*n*Ts) # x(t) işareti örneklenerek x_3n işareti elde edilmiştir.
#plt.figure()
plt.figure(figsize=(12,4))
plt.stem(n,x3n,use_line_collection = True) 
plt.title("$ x_3[n] $") 
plt.xlabel("örnek") 
plt.ylabel("$x_3[n]$") 
plt.show()

# %%
# c)



w=np.linspace(-np.pi,np.pi-(2*np.pi/N),N) 
x_w=np.fft.fft(x3n,N)/N 
x_w=np.fft.fftshift(x_w) # x(w) işaretinin fftshift ile -pi,+pi aralığında gösterilmesi

##çizdirme
plt.figure() #yeni bir figure penceresi açar
plt.stem(w,np.abs(x_w),use_line_collection = True) 
plt.title("$ X_3(w)'nın Genlik Grafiği $") 
plt.xlabel("w") 
plt.show() 


plt.figure() 
plt.stem(w,np.angle(x_w),use_line_collection = True)
plt.title("$ X_3(w)'nın Faz Grafiği $ ") 
plt.xlabel("w") 
plt.show() 
print(np.abs(x_w))
# Out:
# [4.15990838e-16 5.01425756e-16 7.63528123e-16 1.24095812e-16
#  6.97503108e-16 1.97360840e-16 3.95405446e-16 1.16767434e-15
#  5.73861665e-16 6.11767904e-16 1.85217186e-15 5.00000000e-01
#  2.36746416e-15 1.02392697e-15 7.88874356e-16 1.02640402e-15
#  8.72458563e-16 1.05570291e-16 4.45005205e-16 1.89410201e-16
#  2.99357733e-16 1.04333005e-16 5.54422427e-16 6.29105095e-16
#  7.45691024e-16 4.49766334e-16 5.06959361e-16 3.73990866e-16
#  1.07164663e-15 2.25564455e-15 1.27099906e-15 2.99803990e-16
#  1.10995726e-15 7.26794918e-16 7.18121344e-16 5.38280442e-16
#  1.22995999e-15 1.83965327e-16 1.49010982e-15 5.40611060e-16
#  3.03514265e-16 4.88947260e-16 6.70839088e-16 5.66526569e-16
#  5.07879769e-16 6.28651469e-16 2.23489137e-16 4.47241223e-16
#  4.11693220e-16 5.85155555e-16 1.18002935e-15 2.33894126e-15
#  1.41379439e-15 4.12616295e-16 8.52982696e-16 6.93265864e-16
#  6.02224971e-16 5.83540482e-16 9.61677696e-16 2.98101823e-16
# ...

# %% [markdown]
# # d)
# #
# # $x_4[n]= A*sin(B*\pi*n)$ işaretinde A genlik grafiğinden
# # A=0.5 * 2 =1 olarak hesaplanır.
# # B'yi hesaplamak için ise genliğin sıfırdan farklı değer aldığı w değerinin hesaplanması gerekmektedir.

# %%
## Genlik değerlerinin w'nın hangi değerinde sıfırdan farklı olduğunun bulunması ve bu değerler de fazın kaç olduğunun
## belirlenmesi

tentative=np.abs(x_w)
tentavive_phase=np.angle(x_w)
for k in range (len(tentative)):
    if tentative[k]==0.5:
        print(w[k])
        print(tentavive_phase[k])
# Out:
# -2.6016314162540475
# -1.5707963267949085
# 2.6016314162540475
# 1.5707963267949085

# %% [markdown]
# # Yukarıda hesaplanan değer geri elde edilen x4[n]'nin açısal frekansıdır(rad/sample)
# # B=2.60116
# # Yukarıda fourier dönüşümü sonucunda sinyal cos olarak elde edilmiştir .(iki dirac değeri de pozitif geldiği için).Dirac ların mevcut olduğu yerlerde faz 1.57 gelmiştir.Bu da pi/2 demektir.Cos(an-pi/2)=Sin(a*n) olduğu için föyde istenilen şekilde yazıldığı zaman faz gözükmeyecektir.
#
# # Buradan çıkarılan bir başka sonuç , kodda biz Sin fonksiyonu yazsak bile numpy kütüphanesi pi/2 faz farkı alarak cos sinyali üretiyor.

# %% [markdown]
# # $ 1*sin(0.82* \pi *n) $

# %%
# e)

 


Fs=8192 
Ts=1/Fs 
N=128 # örnek sayısının tanımlanması
n=np.arange(0.,3*N) # periyot ayarlanması
xn3=np.sin(9600*np.pi*n*Ts)
xn4=np.sin(2.601631*n) 

##çizdirme
plt.figure()
plt.stem(n,xn3,'bo-')
plt.stem(n,xn4,'ro-')
plt.title("$ x_3[n] and x_4[n] $")
plt.xlabel("örnek")
plt.ylabel("x[n]") 

plt.show() # grafiğin gösterilmesi
# xn3 mavi xn4 kırmızı
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:15: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   from ipykernel import kernelapp as app
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:16: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   app.launch_new_instance()

# %% [markdown]
# #  örnekleme frekansı işaretin frekansının en az 2 katı kadar olmadığı için $x_4[n] ile x_3[n] $ sinyalleri aynı gelmemiştir.(Düzgün örneklenememiştir.)

# %% [markdown]
# # Soru-4

# %%
## Kuantalama Fonksiyonu:
def quantize(x, S):
    X = x.reshape((-1,1))
    S = S.reshape((1,-1))
    dists = abs(X-S)
    nearestIndex = dists.argmin(axis=1)
    quantized = S.flat[nearestIndex]
    return quantized.reshape(x.shape)

# %%
y=np.zeros(9)
## föyde verilen işaretin el ile oluşturulması 
y[0]=1.25
y[1]=3.5
y[2]=4
y[3]=6.7
y[4]=-1.4
y[5]=-3.5
y[6]=-10.5
y[7]=8.5
y[8]=3.8

# %%
k_bit= 3 # işaret değerlerinin kaç bit ile ifade edileceği
Max_range= np.amax(y)-np.amin(y) # işaretin y ekseninde aldığı max değer aralığı
q=pow(2,k_bit) # seviye sayısı
delta = Max_range/q # adım aralığı
S_midrise = -np.amax(y) + delta/2 + np.arange(q)*delta # mid-rise yöntemi için formül
S_midtread = -np.amax(y) + np.arange(q)*delta # mid-tread yöntemi için formül

# %%
y_midtrise = quantize(y, S_midrise) # mid-rise yöntemi 
y_midtread = quantize(y, S_midtread) # mid-tread yöntemi

# %%
n=np.arange(0,9)
#plt.figure() 

fig, ax = plt.subplots()
ax.stem(n,y)
ax.bar(n,y_midtrise,color='orange',edgecolor = "darkorange") 
plt.xlabel("örnek") # grafiğin x ekseninin isimlendirilmesi
plt.title('midrise yöntemiyle kuantalanmış işaret')

fig, ax = plt.subplots()
ax.stem(n,y) # x[n] işaretinin grafiğinin çizdirilmesi
ax.bar(n,y_midtread,color='orange',edgecolor = "darkorange") # kuantalanmış işaretin grafiğinin çizdirilmes
plt.xlabel("örnek") # grafiğin x ekseninin isimlendirilmesi
plt.title('midtread yöntemiyle kuantalanmış işaret')
plt.show()
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:5: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:11: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   # This is added back by InteractiveShellApp.init_path()
